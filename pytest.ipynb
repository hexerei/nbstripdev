# %%
import sys
print(sys.platform)
# Out:
# linux

# %%
import os

for root, dirs, files in os.walk("."):  
    for filename in files:
        print(filename)
# Out:
# .bash_history
# .bash_logout
# .bashrc
# .profile
# .sudo_as_admin_successful
# Untitled.ipynb
# pytest.ipynb
# smb.conf
# selfcheck.json
# 009b43e0b2dcc3de9dd21880dd0331a1c5b4ec0a6798e81cc0f4d991
# 02ea3a40bec709fb2e3011abf56d9ff0e8a057e522b64b520bfc74fe
# 04868589af2aa9aaa5abfc0d92d6e6391419237cc239f46d589efa26
# 06726d442b7e33afe35f1740674b6dee72357a95eef3aca0ef7abf21
# 06a10a01993b98a46b24126de4370c3ed430c734a40d6ac34065ddcf
# 0a690ae203cfcecc7cd36937c2c67e726a0b8c17695217fa14b6dd6f
# 1aaf12502d9d2700532b5c7786558a9bfb4d409422398ffa270ae51d
# 1dd7334300eccd8e1ed88c64659ea7e1bcaaf1eddd748c9a242b5429
# 1f3a010a7cc3ca64eac10d62d9f15870c702fc5a0cf7712c5ae43c10
# 221f8b293bbbe5a659f38826bba2fbb160084ee8836a314b3ac035f5
# 236224bf67d7e2b8edb51af57d4ada1d49f83fa9ce48655d81f36b6d
# 249966c7f1e7970eeae0088cdcd48fa18209582a788c44b34dc549ce
# 2c68f5f22a2976f4d6ba1cdc1f6849b51d0a96a9b75a406470bd408a
# 2d342bd326378d67b7001d4beed3b523a6ddfa968068d9dd7efb6111
# ...
